# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio

image = imageio.imread('super_mario.png') 

grayscale_image = np.dot(image[...,:3], [0.2989, 0.5870, 0.1140])

flattened_image = grayscale_image.flatten()

histogram, bin_edges = np.histogram(flattened_image, bins=256, range=(0, 255))

plt.figure(figsize=(10, 6))
plt.title("Grayscale Image Histogram")
plt.xlabel("Grayscale value")
plt.ylabel("Pixel Count")
plt.xlim([0.0, 255.0])  
plt.plot(bin_edges[0:-1], histogram)
plt.grid(True)
plt.show()
# Out:
# C:\Users\gelar zulfikri\AppData\Local\Temp\ipykernel_8776\1716195219.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread('super_mario.png')  # Ganti dengan path file gambar Anda
